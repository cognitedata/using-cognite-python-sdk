# %% [markdown]
# # Copyright 2022 Cognite AS
#
# ## Import the Libraries and Modules

# %%
# %pip install pandas
# %pip install cognite-sdk

import sys
from pathlib import Path

import pandas as pd
import numpy as np

# Add utils directory to path (resolve from project root)
utils_path = Path(__file__).parent.parent / "utils" if '__file__' in globals() else Path("../utils").resolve()
if str(utils_path) not in sys.path:
    sys.path.insert(0, str(utils_path))

# Import and reload module to pick up changes (run this cell after modifying cognite_auth.py)
import importlib
import cognite_auth
importlib.reload(cognite_auth)
from cognite_auth import interactive_client  # type: ignore
# Out:
# Requirement already satisfied: pandas in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cognite-sdk in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (7.89.0)
# Requirement already satisfied: msal<2.0,>=1.31 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from cognite-sdk) (1.34.0)
# Requirement already satisfied: packaging>=20 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from cognite-sdk) (25.0)
# Requirement already satisfied: protobuf>=4 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from cognite-sdk) (6.33.0)
# Requirement already satisfied: requests<3.0,>=2.27 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from cognite-sdk) (2.32.5)
# Requirement already satisfied: requests_oauthlib<2,>=1 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from cognite-sdk) (1.3.1)
# Requirement already satisfied: typing_extensions>=4 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from cognite-sdk) (4.15.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2.0,>=1.31->cognite-sdk) (2.10.1)
# Requirement already satisfied: cryptography<49,>=2.5 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from msal<2.0,>=1.31->cognite-sdk) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from cryptography<49,>=2.5->msal<2.0,>=1.31->cognite-sdk) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from requests<3.0,>=2.27->cognite-sdk) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from requests<3.0,>=2.27->cognite-sdk) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from requests<3.0,>=2.27->cognite-sdk) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from requests<3.0,>=2.27->cognite-sdk) (2025.10.5)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from requests_oauthlib<2,>=1->cognite-sdk) (3.3.1)
# Requirement already satisfied: pycparser in c:\users\joeo'bryant\onedrive - cognite as\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\lib\site-packages (from cffi>=2.0.0->cryptography<49,>=2.5->msal<2.0,>=1.31->cognite-sdk) (2.23)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Create the Cognite Client

# %%
customer = "oxy"
token_cache_path = Path.home() / ".cognite" / "token_cache" / f"{customer}.json"
client = interactive_client(token_cache_path)

# %% [markdown]
# # Check Identity

# %%
# Get the logged-in user's profile
user_profile = client.iam.user_profiles.me()

# Print user information
print(f"User Identifier: {user_profile.user_identifier}")
print(f"Name: {user_profile.given_name} {user_profile.surname}")
print(f"Email: {user_profile.email}")
print(f"Full profile: {user_profile}")

print(token_cache_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Get the logged-in user's profile
# ----> 2 user_profile = client.iam.user_profiles.me()
#       4 # Print user information
#       5 print(f"User Identifier: {user_profile.user_identifier}")
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\cognite\client\_api\user_profiles.py:44, in UserProfilesAPI.me(self)
#      25 def me(self) -> UserProfile:
#      26     """`Retrieve your own user profile <https://developer.cognite.com/api#tag/User-profiles/operation/getRequesterUserProfile>`_
#      27
#      28     Retrieves the user profile of the principal issuing the request, i.e. the principal *this* CogniteClient was instantiated with.
#    (...)     42             >>> res = client.iam.user_profiles.me()
#      43     """
# ---> 44     return UserProfile._load(self._get(self._RESOURCE_PATH + "/me").json())
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\cognite\client\_api_client.py:186, in APIClient._get(self, url_path, params, headers)
#     183 def _get(
#     184     self, url_path: str, params: dict[str, Any] | None = None, headers: dict[str, Any] | None = None
#     185 ) -> Response:
# --> 186     return self._do_request("GET", url_path, params=params, headers=headers, timeout=self._config.timeout)
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\cognite\client\_api_client.py:221, in APIClient._do_request(self, method, url_path, accept, api_subversion, **kwargs)
#     219 is_retryable, full_url = self._resolve_url(method, url_path)
#     220 json_payload = kwargs.pop("json", None)
# --> 221 headers = self._configure_headers(
#     222     accept,
#     223     additional_headers=self._config.headers.copy(),
#     224     api_subversion=api_subversion,
#     225 )
#     226 headers.update(kwargs.get("headers") or {})
#     228 if json_payload is not None:
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\cognite\client\_api_client.py:275, in APIClient._configure_headers(self, accept, additional_headers, api_subversion)
#     273 headers: MutableMapping[str, Any] = CaseInsensitiveDict()
#     274 headers.update(requests.utils.default_headers())
# --> 275 self._refresh_auth_header(headers)
#     276 headers["content-type"] = "application/json"
#     277 headers["accept"] = accept
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\cognite\client\_api_client.py:289, in APIClient._refresh_auth_header(self, headers)
#     288 def _refresh_auth_header(self, headers: MutableMapping[str, Any]) -> None:
# --> 289     auth_header_name, auth_header_value = self._config.credentials.authorization_header()
#     290     headers[auth_header_name] = auth_header_value
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\cognite\client\credentials.py:192, in _OAuthCredentialProviderWithTokenRefresh.authorization_header(self)
#     190 with self.__token_refresh_lock:
#     191     if self.__should_refresh_token(self.__access_token, self.__access_token_expires_at):
# --> 192         self.__access_token, self.__access_token_expires_at = self._refresh_access_token()
#     193 return "Authorization", f"Bearer {self.__access_token}"
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\cognite\client\credentials.py:627, in OAuthInteractive._refresh_access_token(self)
#     625 # If we're unable to find (or acquire a new) access token, we initiate the interactive auth flow:
#     626 if credentials is None:
# --> 627     credentials = self.__app.acquire_token_interactive(scopes=self.__scopes, port=self.__redirect_port)
#     629 self._verify_credentials(credentials)
#     630 return credentials["access_token"], time.time() + float(credentials["expires_in"])
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\msal\application.py:2216, in PublicClientApplication.acquire_token_interactive(self, scopes, prompt, login_hint, domain_hint, claims_challenge, timeout, port, extra_scopes_to_consent, max_age, parent_window_handle, on_before_launching_ui, auth_scheme, **kwargs)
#    2213 on_before_launching_ui(ui="browser")
#    2214 telemetry_context = self._build_telemetry_context(
#    2215     self.ACQUIRE_TOKEN_INTERACTIVE)
# -> 2216 response = _clean_up(self.client.obtain_token_by_browser(
#    2217     scope=self._decorate_scope(scopes) if scopes else None,
#    2218     extra_scope_to_consent=extra_scopes_to_consent,
#    2219     redirect_uri="http://localhost:{port}".format(
#    2220         # Hardcode the host, for now. AAD portal rejects 127.0.0.1 anyway
#    2221         port=port or 0),
#    2222     prompt=prompt,
#    2223     login_hint=login_hint,
#    2224     max_age=max_age,
#    2225     timeout=timeout,
#    2226     auth_params={
#    2227         "claims": claims,
#    2228         "domain_hint": domain_hint,
#    2229         },
#    2230     data=dict(data, claims=claims),
#    2231     headers=telemetry_context.generate_headers(),
#    2232     browser_name=_preferred_browser(),
#    2233     **kwargs))
#    2234 if "access_token" in response:
#    2235     response[self._TOKEN_SOURCE] = self._TOKEN_SOURCE_IDP
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\msal\oauth2cli\oidc.py:335, in Client.obtain_token_by_browser(self, display, prompt, max_age, ui_locales, id_token_hint, login_hint, acr_values, **kwargs)
#     301 """A native app can use this method to obtain token via a local browser.
#     302
#     303 Internally, it implements nonce to mitigate replay attack.
#    (...)    324 for descriptions on other parameters and return value.
#     325 """
#     326 filtered_params = {k:v for k, v in dict(
#     327     prompt=" ".join(prompt) if isinstance(prompt, (list, tuple)) else prompt,
#     328     display=display,
#    (...)    333     acr_values=acr_values,
#     334     ).items() if v is not None}  # Filter out None values
# --> 335 return super(Client, self).obtain_token_by_browser(
#     336     auth_params=dict(kwargs.pop("auth_params", {}), **filtered_params),
#     337     **kwargs)
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\msal\oauth2cli\oauth2.py:645, in Client.obtain_token_by_browser(self, redirect_uri, auth_code_receiver, **kwargs)
#     636         uri = redirect_uri if _redirect_uri.port != 0 else urlunparse((
#     637             _redirect_uri.scheme,
#     638             "{}:{}".format(_redirect_uri.hostname, receiver.get_port()),
#    (...)    642             _redirect_uri.fragment,
#     643             ))  # It could be slightly different than raw redirect_uri
#     644         self.logger.debug("Using {} as redirect_uri".format(uri))
# --> 645         return self._obtain_token_by_browser(
#     646             receiver, redirect_uri=uri, **kwargs)
#     647 except PermissionError:
#     648     raise ValueError(
#     649         "Can't listen on port %s. You may try port 0." % listen_port)
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\msal\oauth2cli\oauth2.py:673, in Client._obtain_token_by_browser(self, auth_code_receiver, scope, extra_scope_to_consent, redirect_uri, timeout, welcome_template, success_template, error_template, auth_params, auth_uri_callback, browser_name, **kwargs)
#     651 def _obtain_token_by_browser(
#     652         self,
#     653         auth_code_receiver,
#    (...)    667     #
#     668     # Parameters are documented in public method obtain_token_by_browser().
#     669     flow = self.initiate_auth_code_flow(
#     670         redirect_uri=redirect_uri,
#     671         scope=_scope_set(scope) | _scope_set(extra_scope_to_consent),
#     672         **(auth_params or {}))
# --> 673     auth_response = auth_code_receiver.get_auth_response(
#     674         auth_uri=flow["auth_uri"],
#     675         state=flow["state"],  # So receiver can check it early
#     676         timeout=timeout,
#     677         welcome_template=welcome_template,
#     678         success_template=success_template,
#     679         error_template=error_template,
#     680         auth_uri_callback=auth_uri_callback,
#     681         browser_name=browser_name,
#     682         )
#     683     if auth_response is None:
#     684         raise BrowserInteractionTimeoutError("User did not complete the flow in time")
#
# File c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\.venv\Lib\site-packages\msal\oauth2cli\authcode.py:273, in AuthCodeReceiver.get_auth_response(self, timeout, **kwargs)
#     271 begin = time.time()
#     272 while (time.time() - begin < timeout) if timeout else True:
# --> 273     time.sleep(1)  # Short detection interval to make happy path responsive
#     274     if not t.is_alive():  # Then the thread has finished its job and exited
#     275         break
#
# KeyboardInterrupt:

# %% [markdown]
# ## Check Login Status By Running Assets List

# %%
client.assets.list(limit=2)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x1f3cd80f8c0>,
#            <cognite.client.data_classes.assets.Asset at 0x1f3cd74ed50>])

# %% [markdown]
# ## Start Your Own Code Here:

# %%
client.assets.search(name="Europe")

# %%
client.time_series.list(asset_subtree_ids=349354003007241)

# %%
client.time_series.data.retrieve(external_id="Denmark_population", start=946684800000, end=1641081600000)

# %%
from datetime import datetime
dps = client.time_series.data.retrieve(external_id="Denmark_population", start=datetime(2000,1,1), end=datetime(2022,1,2))
dps

# %%
dps.to_pandas().plot()

# %%
from cognite.client.data_classes import DataSet
client.data_sets.list()
prefix = "joe_ob"
ds = client.data_sets.create(DataSet(name=prefix+"example_dataset",external_id=prefix))
ds

# %%
ds_id=ds.id

# %%
from cognite.client.data_classes import TimeSeries
ts = client.time_series.create(TimeSeries(name=prefix+"_timeseries",external_id = prefix+"_timeseries",data_set_id=ds_id ))

# %%
ts

# %%
ts.name = "Joe's Personal Time Series"

# %%
ts = client.time_series.update(ts)
ts

# %%
client.time_series.data.insert(
    external_id="joe_ob_timeseries",
    datapoints=[(1640991600000, 0), (1641078000000, 1), (1641164400000, 2)]
)

# %%
ts

# %%
ts.data.list()

# %%
client.time_series.data.retrieve(external_id="joe_ob_timeseries")

# %%
client.time_series.delete(external_id="joe_ob_timeseries")

# %%
client.data_sets.retrieve(external_id="world_info_academy")

# %%
client.labels.list(name="Hot")

# %%
client.labels.list(name="Cold")
